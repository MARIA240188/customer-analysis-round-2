# %%
import pandas as pd

# %%
df = pd.read_csv('/content/marketing_customer_analysis.csv')

# %% [markdown]
# 1. Show the dataframe shape.

# %%
df.shape
# Out:
# (10910, 26)

# %% [markdown]
# 2. Standardize header names.

# %%
df.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
df = df.rename(columns={'EmploymentStatus': 'Employment Status'})
df = df.rename(columns={'Unnamed: 0': 'Unnamed'})

# %%
df.columns
# Out:
# Index(['Unnamed', 'Customer', 'State', 'Customer Lifetime Value', 'Response',
#        'Coverage', 'Education', 'Effective To Date', 'Employment Status',
#        'Gender', 'Income', 'Location Code', 'Marital Status',
#        'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %% [markdown]
# 3. Which columns are numerical?
# 4.Which columns are categorical?

# %%
 df.dtypes
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# Employment Status                 object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# ...

# %%
# Selecciono las columnas numéricas y las guardo en una variable de tipo lista
columnas_numericas = df.select_dtypes(include=['int', 'float']).columns.tolist()

# Selecciono las columnas categóricas y las guardo en una variable de tipo lista
columnas_categoricas = df.select_dtypes(include=['object']).columns.tolist()

# %%
columnas_numericas
# Out:
# ['Unnamed',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Months Since Last Claim',
#  'Months Since Policy Inception',
#  'Number of Open Complaints',
#  'Number of Policies',
#  'Total Claim Amount']

# %%
columnas_categoricas
# Out:
# ['Customer',
#  'State',
#  'Response',
#  'Coverage',
#  'Education',
#  'Effective To Date',
#  'Employment Status',
#  'Gender',
#  'Location Code',
#  'Marital Status',
#  'Policy Type',
#  'Policy',
#  'Renew Offer Type',
#  'Sales Channel',
#  'Vehicle Class',
#  'Vehicle Size',
#  'Vehicle Type']

# %% [markdown]
# 5. Check and deal with NaN values.

# %%
nan_por_columna = df.isna().sum()

# %%
nan_por_columna
# Out:
# Unnamed                             0
# Customer                            0
# State                             631
# Customer Lifetime Value             0
# Response                          631
# Coverage                            0
# Education                           0
# Effective To Date                   0
# Employment Status                   0
# Gender                              0
# Income                              0
# Location Code                       0
# Marital Status                      0
# Monthly Premium Auto                0
# Months Since Last Claim           633
# Months Since Policy Inception       0
# Number of Open Complaints         633
# Number of Policies                  0
# Policy Type                         0
# Policy                              0
# Renew Offer Type                    0
# Sales Channel                       0
# Total Claim Amount                  0
# Vehicle Class                     622
# Vehicle Size                      622
# ...

# %%
# Reemplazar los NaN por 'No info' en las columnas de info del vehículo:
columnas_a_actualizar = ['Vehicle Class', 'Vehicle Size', 'Vehicle Type']
df[columnas_a_actualizar] = df[columnas_a_actualizar].fillna('No info')
df.head(3)
# Out:
#    Unnamed Customer       State  Customer Lifetime Value Response Coverage  \
# 0        0  DK49336     Arizona              4809.216960       No    Basic
# 1        1  KX64629  California              2228.525238       No    Basic
# 2        2  LZ68649  Washington             14947.917300       No    Basic
#
#   Education Effective To Date Employment Status Gender  ...  \
# 0   College        2011-02-18          Employed      M  ...
# 1   College        2011-01-18        Unemployed      F  ...
# 2  Bachelor        2011-02-10          Employed      M  ...
#
#    Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                   9  Corporate Auto  Corporate L3            Offer3
# 1                   1   Personal Auto   Personal L3            Offer4
# 2                   2   Personal Auto   Personal L3            Offer3
#
#    Sales Channel  Total Claim Amount  Vehicle Class  Vehicle Size  \
# 0          Agent          292.800000  Four-Door Car       Medsize
# ...

# %% [markdown]
# 6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
# Convertir la columna 'Effective To Date' a tipo datetime
df['Effective To Date'] = pd.to_datetime(df['Effective To Date'])

# Extraer el mes y crear una nueva columna 'Month'
df['Month'] = df['Effective To Date'].dt.month

# %%
df.head()
# Out:
#    Unnamed Customer       State  Customer Lifetime Value Response  Coverage  \
# 0        0  DK49336     Arizona              4809.216960       No     Basic
# 1        1  KX64629  California              2228.525238       No     Basic
# 2        2  LZ68649  Washington             14947.917300       No     Basic
# 3        3  XL78013      Oregon             22332.439460      Yes  Extended
# 4        4  QA50777      Oregon              9025.067525       No   Premium
#
#   Education Effective To Date Employment Status Gender  ...  \
# 0   College        2011-02-18          Employed      M  ...
# 1   College        2011-01-18        Unemployed      F  ...
# 2  Bachelor        2011-02-10          Employed      M  ...
# 3   College        2011-01-11          Employed      M  ...
# 4  Bachelor        2011-01-17     Medical Leave      F  ...
#
#    Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                   9  Corporate Auto  Corporate L3            Offer3
# ...
